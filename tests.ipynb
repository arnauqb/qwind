# %%
import qwind_old
import qwind.wind
import qwind.streamline
import qwind.radiation
import qwind.constants
import qwind.aux_numba
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import importlib
importlib.reload(qwind_old)
importlib.reload(qwind.wind)
importlib.reload(qwind.aux_numba)
importlib.reload(qwind.constants)
importlib.reload(qwind.radiation)
importlib.reload(qwind.streamline)
sns.set_context("talk")

# %%
old_line = qwind_old.streamline(M = 1e7, mdot = 0.2, r0 = 457.89473684210526, eta = 0.0313, modes = ['oldint'], intsteps = 1)
old_line.Rx = 879.3977579824169

# %%
wind = qwind.wind.Qwind(M=1e7, mdot=0.2, modes = ['old_integral', 'old_sed'], eta = 0.0313)
line = wind.line(r_0 = 457.89473684210526, v_z_0 = 5e7, z_0 = 1. )
line.radiation.r_x
# Out:
# r_in: 200.000000
#  r_out: 1600.000000
# 879.3977579824169

# %%
old_line.iterate(20000)
# Out:
# ...
# Failed wind!

# %%
line.iterate(20000)
# Out:
# ...
# Failed wind!

# %%
plt.plot(old_line.r_hist, old_line.z_hist, linewidth = 6)
plt.plot(line.r_hist, line.z_hist, linewidth = 4)

# %%
plt.loglog(old_line.t_hist, old_line.xi_hist, linewidth = 6)
plt.loglog(line.t_hist, np.array(line.xi_hist), linewidth = 4)

# %%
plt.loglog(old_line.t_hist, old_line.fm_hist, linewidth = 6)
plt.loglog(line.t_hist, np.array(line.fm_hist), linewidth = 4)

# %%
plt.loglog(np.array(old_line.Frad)[:,0], linewidth = 6)
plt.loglog(np.array(line.Frad)[:,0], linewidth = 4)

# %%
plt.loglog(np.array(old_line.Frad)[:,2], linewidth = 6)
plt.loglog(np.array(line.Frad)[:,2], linewidth = 4)

# %%
plt.loglog(old_line.t_hist, np.array(old_line.tau_X_hist), linewidth = 6)
plt.loglog(line.t_hist, np.array(line.tau_x_hist), linewidth = 4)
